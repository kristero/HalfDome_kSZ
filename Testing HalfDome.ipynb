# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt
from reproject.healpix import reproject_to_healpix

import os
print (os.getcwd())
print (os.listdir())

from astropy.io import fits
# Out:
# /home/cbllover/HalfDome
# ['tSZ_cross_FRB_theta_arcmin_z_dep_vs_random_n1e4_GB_1arcmin.png', 'redshift_distribution_FRB_redshift_logx.png', 'plots\tSZ_Websky_comparison_with.png', 'cosmology.py', 'y_100.fits:Zone.Identifier', 'cached_tSZ_HalfDome_cosmo_sobol_battaglia_sobol_4_row0001_cosmo_fid.jld2', 'plots\tSZ_Fullsky_Osato_comparison.png', 'kappa_zs0.5_s100.fits:Zone.Identifier', '.git', 'tmp_dm_beam.jld2', 'tmp_plot_test_local.jl', 'HalfDome_kSZ_nside4096_sigmoid_r0_3_position_hcorr_13Msol_cutoff_HALO.fits', 'halos_websky.hdf5', 'kappa_zs0.5_s100.fits', '=5,', 'cached_kSZ_Websky_tau_base_f_e.jld2', 'other_sim_kSZ_sigmoid.jl', 'cached_kSZ_Websky_tau_base.jld2', 'tSZ_cross_FRB_ell_websky_vs_halfdome.png', 'plots\\kSZ_Osato_comparison.png', 'Websky_tests.ipynb', 'Testing_websky_diff_models.ipynb', 'Classy_SZ_tests.ipynb', 'batched_data', 'cached_tSZ_Websky_cosmo_base_gaussbeam_0p5arcmin.jld2', 'cached_model_density-z_websky.jld2', 'tSZ_cross_FRB_halo_test.jl', 'Halfdome_analysis-checkpoint.ipynb', 'ksz_websky.fits:Zone.Identifier', 'globusconnectpersonal-latest.tgz', 'cached2_model_sigmoid_Ntheta512_pad256_integral_reduced_acc.jld2', 'cached_FRB_true_DM_Websky_cosmo.jld2', 'tSZ_visuals', 'y_100.fits', 'analyze_frb_dm_mass_relation.py', 'cached_tSZ_Websky_cosmo_gaussian_profile.jld2', 'HalfDome_y_tSZ_mass_corr.fits', 'VIsuals for tSZ.ipynb', 'y_tSZ_total_sigmoid.fits', 'cached_FRB_DM_Websky_cosmo_default.jld2', 'globusconnectpersonal-3.2.8', 'tsz.fits', 'battaglia16_dm_shell_test_profile_cache.jld2', 'cached_HalfDome_kSZ_tau_nosigmoid.jld2', 'tSZ_Websky_comparison_with (2).png', 'tmp_dm_nobeam.jld2', 'battaglia_tau_interpolator_adrian_fix.jld2', 'Halfdome_analysis.ipynb', 'ksz_websky.fits', 'lightcone_100.hdf5:Zone.Identifier', 'beam_check.jl', 'kSZ_Box0_35x35_MAGNETICUM.fits:Zone.Identifier', 'Sobol_tSZ', 'Tcmb_tSZ_nside4096_sigmoid_r03_13Msol_cutoff_HALO.fits', 'SOConvertNFW.jl', 'Sobol seq & GB applying.ipynb', 'y_tSZ_small_sigmoid.fits', 'profiles.jl', 'halfdome_halo_tSZ - Copy.jl:Zone.Identifier', '.png', 'halfdome_halo_kSZ_sigmoid.jl', 'tSZ_cross_FRB_ell.png', 'cached_model_sigmoid_Ntheta512_pad256_integral_reduced_acc.jld2', 'only_sigmoid_battaglia_model.jl', 'cached_b16.jld2', 'websky_halos_test_kSZ.jl', 'halfdome_halo_kSZ_sigmoid_chunked.jl', 'lightcone_100.hdf5', 'tSZ_comparison_Osato_HP.png', '__pycache__', '.gitignore', 'field_ksz_Adrian.jl', 'kSZ_field_idark.py', 'Websky_kSZ_comparison.png', 'tmp_gr_100_test.jl', '.ipynb_checkpoints', 'cached_model_Ntheta512_pad256_integral_increased_acc.jld2', 'cached_FRB_true_DM_Websky_cosmo_gaussbeam_0p5arcmin.jld2', 'frames', 'tsz.fits:Zone.Identifier', 'tmp_gr_png_test.jl', 'Websky_to_hdf5.jl', 'kSZ_Adrian_code.py', 'tSZ_cross_FRB_ell_different_comparisons.png', 'halos-light.pksc:Zone.Identifier', 'plots\tSZ_HalfDome_vs_Websky.png', 'cached_tSZ_HalfDome_cosmo_base_plus_battaglia_P0_amp_17p195_cosmo_fid.jld2', 'cached_tSZ_HalfDome_cosmo_base_cosmo_fid.jld2', 'other_sims', 'mass_distribution_websky.png', 'cached_tSZ_HalfDome_cosmo_base.jld2', 'y_tSZ_nside1024_sigmoid_m1e13_corr_units_increased_acc.fits', 'cached_FRB_true_DM_Websky_cosmo_gaussian_profile.jld2', 'Cl_tsz.npz', 'kSZ.py', 'halfdome_halo_tSZ.jl', 'HalfDome_y_tSZ.fits', 'cached_tSZ_Websky_cosmo.jld2', 'README (1).txt', 'make_random_frb_dm_map_z1.jl', 'compute_frb_dm_xgpaint_backend.jl', 'websky_physc_param_variations', 'Testing_websky.ipynb', 'plots', 'SBI_analysis', 'cached_test_no_sigmoid.jld2', 'kSZ_Adrian_fix_compared_to_full_websky.png', 'DM_shell_test.jl', 'cached_tSZ_Websky_cosmo_base.jld2', 'cached_tSZ_Websky_cosmo_default.jld2', 'sanity_check_beamed_maps.jl', 'Comparison with Websky.ipynb', 'HPC_output', 'halfdome_halo_and_field_kSZ.jl', 'profiles_tau_sigmoid.jl', 'tSZ and FRB maps.ipynb', 'HPC_output.lnk', 'kSZ.py:Zone.Identifier', 'halfdome_halo_kSZ.jl', 'cached_FRB_true_DM_Websky_cosmo_gaussbeam_1p0arcmin.jld2', 'tSZ x FRB analysis.ipynb', 'Comparison_between_different_datasets.png', 'illustris_python', 'cl.fits', 'gaussian_beam_pro ...

# %% [markdown]
# # tSZ maps

# %%
fname = "y_100.fits"
with fits.open(fname, memmap=True) as hdul:
    print("Number of HDUs:", len(hdul))
    print(hdul.info())
# Out:
# Number of HDUs: 1
# Filename: y_100.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      25   (43200, 21601)   float64
# None

# %%
fname = "y_100.fits"
hdu = fits.open(fname, memmap=True)[0]
hdr = hdu.header

# Detect frame from header (GLON/GLAT → galactic; otherwise fallback to ICRS)
ctype1 = (hdr.get('CTYPE1','') or '').upper()
coord_system = 'galactic' if 'GLON' in ctype1 else 'icrs'

NSIDE = 1024  
y_map, footprint = reproject_to_healpix((hdu.data, hdr),
                                        coord_system,
                                        nside=NSIDE, 
                                       nested = False)  # 'ring' indexing

y_map = y_map.astype('f4', copy=False)

# %%
hp.mollview(y_map, title=f"tSZ y, NSIDE={NSIDE}",
            unit="Compton-y", norm="hist", cmap = "plasma")
hp.graticule()
plt.show()

# %%
lmax = 3*hp.get_nside(y_map) - 1
cl = hp.anafast(y_map, lmax=lmax)
ell = np.arange(len(cl))

# %%
Dl = ell*(ell+1)*cl/(2*np.pi)*10**12
#Dl = cl/(2*np.pi)*10**12
plt.loglog(ell, Dl)
plt.xlabel(r"$\ell$"); plt.ylabel(r"$\ell(\ell+1)C_\ell/2\pi$")
plt.title("tSZ y-map power spectrum")
plt.show()

# %% [markdown]
# # Lensing map

# %%
fname = "kappa_zs0.5_s100.fits"             # lensing

# Read as float32 with memory mapping; load only field 0
lensing_map = hp.read_map(fname)

hp.mollview(lensing_map, coord=['G','E'], title='Lensing', norm='hist', xsize=2000)
hp.graticule()

# %% [markdown]
# # Lightcone

# %%
fname = "lightcone_100.hdf5"   # adjust filename
NSIDE = 1024                                 
zmin, zmax = 0.0, 1.0
Mmin = 1e09                                 

# allocate map
npix = hp.nside2npix(NSIDE)
map_counts = np.zeros(npix, dtype=np.float32)
map_mass = np.zeros(npix, dtype=np.float32)

with h5py.File(fname, "r") as f:
    pos  = f["Position"]      # [N,3] Cartesian positions (unit sphere, radians)
    z    = f["redshift"]
    m200 = f["halo_mass_m200c"]

    N = pos.shape[0]
    print(f"Total halos: {N:,}")

    chunk = int(1e08)
    for i in range(0, N, chunk):
        p  = pos[i:i+chunk][...]
        zz = z[i:i+chunk][...]
        mm = m200[i:i+chunk][...]

        # convert Cartesian → spherical
        x, y, zc = p[:,0], p[:,1], p[:,2]


        sel = np.isfinite(x) & np.isfinite(y) & np.isfinite(zc) & (zz >= zmin) & (zz < zmax) & (mm >= Mmin)
        if not np.any(sel):
           continue

        ipix  = hp.vec2pix(NSIDE, x[sel], y[sel], zc[sel], nest=False)
        np.add.at(map_counts, ipix, 1.0)

        # fast accumulate using bincount
        bins = np.bincount(ipix, weights=mm[sel], minlength=npix).astype(np.float32)
        map_mass += bins
        # mass-weighted
        np.add.at(map_mass, ipix, mm[sel])
# Out:
# Total halos: 85,224,251

# %%
print(np.corrcoef(map_counts, map_mass)[0,1])  # should be < 1
# Out:
# 0.605986099122364

# %%
# convert to per-deg²
pix_area_sr = 4*np.pi / map_counts.size
deg2_per_pix = pix_area_sr * (180/np.pi)**2
map_per_deg2 = map_counts / deg2_per_pix
map_per_deg2_smoothed = hp.smoothing(map_per_deg2, fwhm=np.radians(3.))


hp.mollview(map_per_deg2_smoothed, title=f"Halo surface density (z∈[{zmin},{zmax}), NSIDE={NSIDE})",
            unit="halos / deg$^2$", norm="hist", cmap="bwr")
hp.graticule()
plt.show()

# %%
# convert to mass per deg^2 (nice colorbar)
pix_area_sr   = 4*np.pi / npix
deg2_per_pix  = pix_area_sr * (180/np.pi)**2
map_mass_deg2 = map_mass / deg2_per_pix
map_mass_deg2_smoothed = hp.smoothing(map_mass_deg2, fwhm=np.radians(3.))

hp.mollview(map_mass_deg2_smoothed,
            title=f"Projected halo mass (M200c) per deg²  z∈[{zmin},{zmax}), NSIDE={NSIDE}",
            unit="M$_\\odot$/h per deg$^2$",
            norm="hist",
            cmap="plasma")
hp.graticule()
plt.show()

# %%
lmax = 3*hp.get_nside(map_per_deg2) - 1
cl = hp.anafast(map_per_deg2, lmax=lmax)
ell = np.arange(len(cl))

Dl = ell*(ell+1)*cl/(2*np.pi)
#Dl = cl/(2*np.pi)*10**12
plt.loglog(ell, Dl)
plt.xlabel(r"$\ell$"); plt.ylabel(r"$\ell(\ell+1)C_\ell/2\pi$")
plt.title("Halo density power spectrum")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 lmax = 3*hp.get_nside(map_per_deg2) - 1
#       2 cl = hp.anafast(map_per_deg2, lmax=lmax)
#       3 ell = np.arange(len(cl))
#
# NameError: name 'map_per_deg2' is not defined

# %% [markdown]
# # Julia/xgpaint results

# %%
def plot_kSZ(fname, title = "kSZ map TOTAL (NSIDE=2048)", unit = r"ΔT, $(\mu K)$", cmap = "plasma", scale = 1):
    # The tSZ Compton-y map (field 0)
    y_map = hp.read_map(fname, field=0, nest=False, dtype=np.float32)
    
    # Plot it directly
    hp.mollview(y_map*scale, title=title, unit=unit, norm="hist", cmap = cmap, format="%.1e")
    hp.graticule()
    plt.show()
    return y_map

# %%
def power_spectra_computation(fname):
    data_full = hp.read_map(fname, field=0, nest=False, dtype=np.float32)

    lmax = 3*hp.get_nside(data_full) - 1
    cl = hp.anafast(data_full, lmax=lmax)
    ell = np.arange(len(cl))
    Dl = ell*(ell+1)*cl/(2*np.pi)
    return Dl, ell

# %%
def plot_power_spectra(y_map, title = "Power spectrum of total kSZ map"):
    lmax = 3*hp.get_nside(y_map) - 1
    cl = hp.anafast(y_map, lmax=lmax)
    ell = np.arange(len(cl))

    Dl = ell*(ell+1)*cl/(2*np.pi)*10**12
    #Dl = cl/(2*np.pi)*10**12
    plt.loglog(ell, Dl*10**6)
    plt.xlabel(r"$\ell$"); plt.ylabel(r"$\ell(\ell+1)C_\ell/2\pi, (\mu K^2)$")
    plt.xlim((70, 6000))
    plt.title(title)
    plt.show()
    return Dl

# %% [markdown]
# # Seperating between halo and fields

# %%
# The 1- halo code

fname = "y_tSZ_total_sigmoid.fits"
halo_kSZ_map = plot_kSZ(fname, title  = r"kSZ map with sigmoid (NSIDE = 4096)", unit = r"ΔT, $(K)$")

# %%
# The 1- halo code

fname = "y_tSZ_small_regular_interpolated.fits"
halo_kSZ_map = plot_kSZ(fname, title  = r"kSZ map Battaglia (NSIDE = 1024)", unit = r"ΔT, $(\mu K)$", cmap = "bwr", scale = 10**6)

# %%
# The 1- halo code

fname = "y_tSZ_small_sigmoid.fits"
halo_kSZ_map = 2.7255*10**(-3)*plot_kSZ(fname, title  = r"kSZ map SigmoidBattaglia (NSIDE = 1024)", unit = r"ΔT, $(\mu K)$", cmap = "bwr", scale = 10**6)

# %%
title = "Battaglia minus SigmoidBattaglia map"
unit = r"ΔT, $(\mu K)$"
cmap = "bwr"

fname1 = "y_tSZ_small_sigmoid.fits"
fname2 = "y_tSZ_small_regular_interpolated.fits"

y_map1 = hp.read_map(fname1, field=0, nest=False, dtype=np.float32)
y_map2 = hp.read_map(fname2, field=0, nest=False, dtype=np.float32)

# Plot it directly
hp.mollview((y_map2 - y_map1)*10**6, title=title, unit=unit, norm="hist", cmap = cmap, format="%.1e")
hp.graticule()
plt.show()

# %%
np.multiply(y_map1, 2.7255*10**(-3)) == 2.7255*10**(-3)*y_map1
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
lmax1 = 3*hp.get_nside(y_map1) - 1
cl1 = hp.anafast(y_map1, lmax=lmax1)
ell1 = np.arange(len(cl1))

lmax2 = 3*hp.get_nside(y_map2) - 1
cl2 = hp.anafast(y_map2, lmax=lmax2)
ell2 = np.arange(len(cl2))

Dl1 = ell1*(ell1+1)*cl1/(2*np.pi)*10**12
Dl2 = ell2*(ell2+1)*cl2/(2*np.pi)*10**12
#Dl = cl/(2*np.pi)*10**12

# %%
plt.loglog(ell1, abs(Dl1 - Dl2), label = "Battaglia - SigmoidB")
# plt.loglog(ell2, Dl2, "-.", label = "SigmoidBattaglia")


plt.xlabel(r"$\ell$"); plt.ylabel(r"$\ell(\ell+1)C_\ell/2\pi, (\mu K^2)$")
# plt.xlim((70, 6000))
# plt.title(title)
plt.legend()
plt.show()

# %%
plt.loglog(ell1, Dl1, label = "Battaglia")
plt.loglog(ell2, Dl2, "-.", label = "SigmoidBattaglia")


plt.xlabel(r"$\ell$"); plt.ylabel(r"$\ell(\ell+1)C_\ell/2\pi, (\mu K^2)$")
# plt.xlim((70, 6000))
# plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# # WEB-sky comparison

# %%
fname = "ksz_websky.fits"
websky_full = plot_kSZ(fname, title  = r"kSZ map Websky", unit = r"ΔT, $(\mu K)$", cmap = "bwr")

# %%
fname1 = "y_tSZ_nside4096_sigmoid.fits"

fname = "ksz_websky.fits"
Dl1, ell1 = power_spectra_computation(fname)


# Dl2, ell2 = power_spectra_computation(fname1)

# %%
fname2 = "y_tSZ_small_sigmoid.fits"
Dl3, ell3 = power_spectra_computation(fname2)

# %%
fname3 = "y_tSZ_nside4096_sigmoid_m1e13_corr_units.fits"


Dl4, ell4 = power_spectra_computation(fname3)

# %%
fname4 = "y_tSZ_nside4096_sigmoid_m1e13.fits"

Dl5, ell5 = power_spectra_computation(fname4)

# %%
fname5 = "y_tSZ_nside4096_sigmoid_m1e13_corr_units_increased_acc.fits"

Dl6, ell6 = power_spectra_computation(fname5)

# %%
fname6 = "y_tSZ_nside1024_sigmoid_m1e13_corr_units_increased_acc.fits"
Dl7, ell7 = power_spectra_computation(fname6)

# %%
fname7= "y_tSZ_nside4096_sigmoid_13Msol_cutoff_HALO _m200m.fits"
Dl8, ell8 = power_spectra_computation(fname7)

# %%
fname9= "other_sims/148_ksz_healpix_nopell_Nside4096_DeltaT_uK.fits"
Dl9, ell9 = power_spectra_computation(fname9)

# %%
fname10 = "other_sim_Tcmb_tSZ_nside4096_sigmoid_13Msol_cutoff_HALO_m200m.fits"
Dl10, ell10 = power_spectra_computation(fname10)

# %%
import astropy.io.fits as fits
fits.info(fname7)
# Out:
# Filename: kSZ_Box0_35x35_MAGNETICUM.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       9   (6144, 6144)   float32

# %%
plt.figure(figsize = (10, 6))
factor_mult = (2.7255*1e6)**2
CMB_factor = 1/(2.73**2)
plt.scatter(ell1, Dl1, s = 2, label = "Websky full", c= 'grey')
# plt.scatter(ell2, Dl2*factor_mult, s = 2, label = "HalfDome")
# plt.scatter(ell3, Dl3, s=2, label = "HalfDome nside = 1024")
# plt.scatter(ell4, Dl4*factor_mult, s = 2, label = "HalfDome M>1e13 corrected", c = "orange")
# plt..scatter(ell5, Dl5*factor_mult, s = 2, label = "HalfDome M>1e13", c= "red")
plt.scatter(ell6, Dl6*factor_mult, s = 2, label = "HalfDome halo logM_200c > 13", c = "orange")
plt.scatter(ell8, Dl8*factor_mult, s = 2, label = "HalfDome halo logM200m > 13", c = "purple")
plt.scatter(ell9, Dl9, s = 2, label = "Simons Observatory Forecasts (2019)", c = "green")
plt.scatter(ell10, Dl10*factor_mult, s = 2, label = "Sehgal 2010 halo ", c = "blue")



plt.xlabel(r"$\ell$"); plt.ylabel(r"$\ell(\ell+1)C_\ell/2\pi, (\mu K^2)$")
plt.xlim((70, 6000))
plt.xscale("log")
# plt.title(title)
plt.legend(frameon = False)
plt.grid()
# plt.savefig("Comparison_between_HalfDome_and_websky_M13_cut.png")
plt.show()

# %% [markdown]
# ### (Websky has m200m)
#
# Data for other sims from https://lambda.gsfc.nasa.gov/simulation/full_sky_sims_ov.html

# %%
plt.scatter(ell4, abs((Dl4*factor_mult - Dl1)), s = 2, label = "HalfDome M>1e13")
plt.xlim((70, 6000))
plt.xlabel(r"$\ell$")
plt.ylabel(r"Absolute $\Delta C_{\ell}$")
plt.xscale("log")

# %% [markdown]
# ## Cosmology
# #### Websky:
# (Ωm,Ωb,σ8,ns,h,τ) =(0.31,0.049,0.81,0.965,0.68,0.055)
#
# Halo mass = 1.2 10^(12) M_sol(z < 4). Up to z = 4.6 it becomes 4e12 M_sol
# #### Halfdome:
#  h=0.6774, Ωm=0.3089, Ωb=0.0486, σ8=0.8159, ns=0.9667, Mν=0
#
#  Halo Mass = 1.95 * 10^10 M_sol (in reality its around 5e12 M_sol from histograms of data)

# %%
# kSZ

# %%
fname6 = "batched_data/HalfDome_kSZ_nosigmoid_nside4096_m1e13.fits"
Dl7, ell7 = power_spectra_computation(fname6)

# %%
plt.figure(figsize = (10, 6))
factor_mult = (2.7255*1e6)**2
CMB_factor = 1/(2.73**2)
plt.scatter(ell1, Dl1, s = 2, label = "Websky full", c= 'grey')

plt.scatter(ell7, Dl7*factor_mult, s = 2, label = "HalfDome halo logM200m > 13", c = "purple")




plt.xlabel(r"$\ell$"); plt.ylabel(r"$\ell(\ell+1)C_\ell/2\pi, (\mu K^2)$")
plt.xlim((70, 6000))
plt.xscale("log")
# plt.title(title)
plt.legend(frameon = False)
plt.grid()
# plt.savefig("Comparison_between_HalfDome_and_websky_M13_cut.png")
plt.show()

# %%
title  = r"kSZ map Websky"
unit = r"ΔT, $(\mu K)$"
cmap = "bwr"
scale = factor_mult

# The tSZ Compton-y map (field 0)
y_map = hp.read_map(fname6, field=0, nest=False, dtype=np.float32)

# %%
# Plot it directly
hp.mollview(y_map*2.7255*1e6, title="kSZ map HalfDome", unit=unit, norm="hist", cmap = "plasma", format="%.1e")
hp.graticule()
plt.savefig("plots/kSZ_HalfDome_map_Mmin13.jpg", dpi= 400)
plt.show()

# %% [markdown]
# # Resolution tests

# %%
import os
print (os.getcwd())
# Out:
# /home/cbllover/HalfDome

# %%
fname_hr = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside1024_13Msol_cutoff_HALO_base_cosmo_fid_gaussbeam_1p6arcmin_fullmap_high_res.fits"
Dl_hr, ell_hr = power_spectra_computation(fname_hr)

# %%
# rtol = 1e-6 order= 7
fname_lr = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside1024_13Msol_cutoff_HALO_base_cosmo_fid_gaussbeam_1p6arcmin_fullmap_finalonly_m200c.fits"
Dl_lr, ell_lr = power_spectra_computation(fname_lr)

# %%
fname_lr3_4 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_fullmap_rtol3_o5.fits"
Dl_lr3_4, ell_lr3_4 = power_spectra_computation(fname_lr3_4)

# %%
fname_lr3_o3 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_fullmap_rtol3_o3.fits"
Dl_lr3_o3, ell_lr3_o3 = power_spectra_computation(fname_lr3_o3)

# %%
fname_lr4_o3 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_fullmap_rtol4_o3.fits"
Dl_lr4_o3, ell_lr4_o3 = power_spectra_computation(fname_lr4_o3)

# %%
fname_lr5_o3 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_fullmap_rtol5_o3c.fits"
Dl_lr5_o3, ell_lr5_o3 = power_spectra_computation(fname_lr5_o3)

# %%
fname_lr8_o7 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_fullmap_rtol8_o7.fits"
Dl_lr8_o7, ell_lr8_o7 = power_spectra_computation(fname_lr8_o7)

# %%
fname_lr3_o7 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_fullmap_rtol3_o7.fits"
Dl_lr3_o7, ell_lr3_o7 = power_spectra_computation(fname_lr3_o7)

# %%
fname_m128 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_fullmap_m128.fits"
Dl_m128, ell_m128 = power_spectra_computation(fname_m128)

# %%
fname_m128_p128 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_p128_m128.fits"
Dl_m128_p128, ell_m128_p128 = power_spectra_computation(fname_m128_p128)

# %%
fname_m128_p128_t256 = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_cosmo_fid_nobeam_fullmap_m128_p128_t256.fits"
Dl_m128_p128_t256, ell_m128_p128_t256 = power_spectra_computation(fname_m128_p128_t256)

# %%
fname = "/home/cbllover/HalfDome/batched_data/halfdome_tSZ_nside4096_13Msol_cutoff_HALO_base_nobeam_nfrb10000_seed42_random_zcut0p5_zmax2p5_m200c.fits"

Dl_big, ell_big = power_spectra_computation(fname)

# %%
# plt.loglog(ell_hr, Dl_hr*1e12, label = "high res")
# plt.loglog(ell_lr, Dl_lr*1e12, "-.", label = "rtol=1e-6 o=7")

plt.loglog(ell_big, Dl_big*1e12, label = "main", c = "red")
# plt.loglog(ell_lr3_4, Dl_lr3_4*1e12, "-.", label = "rtol=1e-3 o=5")
# plt.loglog(ell_lr3_o3, Dl_lr3_o3*1e12, "-.", label = "rtol=1e-3 o=3")
# plt.loglog(ell_lr5_o3, Dl_lr5_o3*1e12, label = "rtol=1e-5 o=3")
# plt.loglog(ell_lr4_o3, Dl_lr4_o3*1e12, label = "rtol=1e-5 o=3")

plt.loglog(ell_lr4_o3, Dl_m128_p128*1e12, label = "m128, p128")

plt.xlabel(r"$\ell$"); plt.ylabel(r"$\ell(\ell+1)C_\ell/2\pi, (\mu K^2)$")
plt.xlim((70, 6000))
plt.ylim((5e-2, 3))
# plt.title(title)
plt.legend()
plt.show()

# %%
# plt.loglog(ell_lr3_4, abs((Dl_big -Dl_lr3_4))*1e12,  label = "o3")
plt.loglog(ell_lr3_4, abs((Dl_big -Dl_lr8_o7))*1e12, "--", label = "lr8_o7")
plt.loglog(ell_lr3_4, abs((Dl_big -Dl_lr3_o7))*1e12, "--", label = "Dl_lr3_o7")
plt.loglog(ell_lr3_4, abs((Dl_lr8_o7 -Dl_lr3_o7))*1e12, "--", label = "Dl_lr8_o7 - Dl_lr3_o7")

plt.legend()
# plt.loglog(ell_lr3_4, abs((Dl_big -Dl_lr5_o3))*1e12, "--", label = "o5")
# plt.xlim((70, 6000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 2
#       1 # plt.loglog(ell_lr3_4, abs((Dl_big -Dl_lr3_4))*1e12,  label = "o3")
# ----> 2 plt.loglog(ell_lr3_4, abs((Dl_big -Dl_lr8_o7))*1e12, "--", label = "lr8_o7")
#       3 plt.loglog(ell_lr3_4, abs((Dl_big -Dl_lr3_o7))*1e12, "--", label = "Dl_lr3_o7")
#       4 plt.loglog(ell_lr3_4, abs((Dl_lr8_o7 -Dl_lr3_o7))*1e12, "--", label = "Dl_lr8_o7 - Dl_lr3_o7")
#
# NameError: name 'ell_lr3_4' is not defined

# %%
interp_time = [89, 162, 182, 183]
error_batch = 1e12*np.array([np.mean((Dl_big -Dl_lr3_o3)), np.mean((Dl_big -Dl_lr4_o3)), np.mean((Dl_big -Dl_lr5_o3)),
                             np.mean((Dl_big -Dl_lr3_4))])

plt.plot(interp_time, abs(error_batch)*100)
plt.scatter(interp_time, abs(error_batch)*100)

plt.yscale("log")
plt.xlabel("Computation time, sec")
plt.ylabel(r"$\Delta D_{\ell}$, %")
# Out:
# Text(0, 0.5, '$\\Delta D_{\\ell}$, %')

# %%
### C_l tests

# %%
generated_data = np.load("HPC_output/HalfDome/ydata_4096/sbi_battaglia_y100_4096.npz")

# %%
generated_data.files
# Out:
# ['theta',
#  'theta_columns',
#  'ell',
#  'cl_mean',
#  'cl_y100',
#  'cl_stack',
#  'cl_concat',
#  'cl_log10_mean',
#  'cl_log10_y100',
#  'cl_log10_concat',
#  'seed_ids',
#  'target_floor',
#  'param_key',
#  'sobol_global_row',
#  'sobol_split',
#  'sobol_row']

# %%
mean_data = generated_data["cl_mean"]
y100_data = generated_data["cl_y100"]

print (y100_data[1009].shape)
# Out:
# (4095,)

# %%
generated_data["theta"][1009]
# Out:
# array([ 2.79581386e+01,  1.55268803e-01,  3.85984256e+00,  1.72146233e-01,
#        -3.73934602e-02,  1.37082533e-02, -4.73341709e-01,  1.08180647e+00,
#         1.43260471e-01])

# %%
N_sample = 1009
cl_1009 = y100_data[N_sample]

ell = np.arange(len(cl_1009))
Dl_1009 = ell*(ell+1)*cl_1009/(2*np.pi)

plt.loglog(ell, Dl_1009*1e12)
plt.loglog(ell, ell*(ell+1)*mean_data[1009]/(2*np.pi)*1e12)

# %%
fname_local = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_cl_m200c_base_plus_battaglia_P0_amp_27p9581386__battaglia_P0_alpha_m_0p172146233__battaglia_P0_alpha_z_m0p473341709__battaglia_x_c_amp_0p155268803__battaglia_x_c_alpha_m_m0p0373934602__battagli_hf9523b723d72.fits"
cl_local_1009 = hp.read_cl(fname_local)[1][2:]

Dl_local_1009 = ell*(ell+1)*cl_local_1009/(2*np.pi)

# %%
fname_local = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_tSZ_cl_m200c_base_plus_battaglia_P0_amp_27p9581386__battaglia_P0_alpha_m_0p172146233__battaglia_P0_alpha_z_m0p473341709__battaglia_x_c_amp_0p155268803__battaglia_x_c_alpha_m_m0p0373934602__battagli_hf9523b723d72.fits"
cl_local_1009_p2 = hp.read_cl(fname_local)[1][1:-1]

Dl_local_1009_p2  = ell*(ell+1)*cl_local_1009_p2/(2*np.pi)

# %%
fname_local = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_rtol3_o7_logM128_cluster.fits"
cl_cluster_1009_r3_o7_m128 = hp.read_cl(fname_local)[1][2:]

Dl_cluster_1009_r3_o7_m128  = ell*(ell+1)*cl_cluster_1009_r3_o7_m128/(2*np.pi)

# %%
fname_local = "tSZ_visuals/tSZ_visuals/full_tsz_outputs/halfdome_rtol12_o9_logM256_pad256_cluster.fits"
cl_cluster_1009_rtol12_o9_logM256_pad256 = hp.read_cl(fname_local)[1][2:]

Dl_cluster_1009_rtol12_o9_logM256_pad256  = ell*(ell+1)*cl_cluster_1009_rtol12_o9_logM256_pad256/(2*np.pi)

# %%
hp.read_cl(fname_local)[1].shape
# Out:
# (4097,)

# %%
mask = (
    np.isfinite(Dl_1009)
    & np.isfinite(Dl_local_1009)
    & (np.abs(Dl_local_1009) > 0)
)

percent_diff = np.abs(Dl_1009[mask] - Dl_local_1009[mask]) / np.abs(Dl_local_1009[mask]) * 100

print("Percentage difference: ", np.mean(percent_diff))
# Out:
# Percentage difference:  3.4272228537210534

# %%
plt.plot(ell, abs(Dl_1009 - Dl_cluster_1009_r3_o7_m128)/abs(Dl_cluster_1009_r3_o7_m128)*100, "--")
# plt.plot(ell, abs(Dl_1009 - Dl_local_1009_p2)/abs(Dl_local_1009)*100, "--")

plt.yscale("log")
# plt.xscale("log")
# Out:
# /tmp/ipykernel_2462/986446278.py:1: RuntimeWarning: invalid value encountered in divide
#   plt.plot(ell, abs(Dl_1009 - Dl_cluster_1009_r3_o7_m128)/abs(Dl_cluster_1009_r3_o7_m128)*100, "--")

# %%
plt.loglog(ell, Dl_cluster_1009_rtol12_o9_logM256_pad256*1e12, label = "local")
plt.loglog(ell, Dl_1009*1e12, "--", label = "data", alpha = 0.5)

# plt.loglog(ell_lr8_o7, Dl_lr8_o7*1e12, label = "rtol=1e-8 o=7")

# plt.xlim((1000, 6000))
# plt.ylim((0.8e-1, 6e-1))
plt.legend()

# %%
np.mean(abs(Dl_1009 - Dl_cluster_1009_r3_o7_m128)/abs(Dl_cluster_1009_r3_o7_m128)*100)
# Out:
# /tmp/ipykernel_2462/3959994131.py:1: RuntimeWarning: invalid value encountered in divide
#   np.mean(abs(Dl_1009 - Dl_cluster_1009_r3_o7_m128)/abs(Dl_cluster_1009_r3_o7_m128)*100)
# nan
